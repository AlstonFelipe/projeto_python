# %%
listas_carros = ["Toyota", "Honda", "Ford", "BMW"]

tuplas_carros = tuple (listas_carros)
print (f"Lista de carros:, {listas_carros}")
# Out:
# Lista de carros:, ['Toyota', 'Honda', 'Ford', 'BMW']

# %%
tupla_carros = ("Toyota", "Honda", "Ford", "BMW")
lista_carros = list (tupla_carros)
print (f"Tupla de carros:, {tupla_carros}")
# Out:
# Tupla de carros:, ('Toyota', 'Honda', 'Ford', 'BMW')
